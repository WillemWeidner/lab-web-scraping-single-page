# %% [markdown]
# # lab-api-wrappers

# %%
# Libraries

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

from random import randint
from time import sleep

import pandas as pd
from pandas import json_normalize

# %%
# https://developer.spotify.com/dashboard
# To get my codes

# %%
# Take the same Code like in 6.5

# %%
# You need at least 20.000 songs.

# %%
# Do the steps for one playlist after the other

# %%
# Title, artist and Audio features
    # It is the audio features you are going to model

# %%
# Example playlist
    #'https://open.spotify.com/playlist/1QfbJBydxHUJuQ0DeNNZTm'

# %%
# Use the functions that get all of them (not the in between onces)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
# authentification with secrets

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# This creates actually the connection to spotify (spotify wrapper is called sp)

# It uses the key client id to substitue the id
# It will substitue secret

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %% [markdown]
# 1. Playlist https://open.spotify.com/playlist/1QfbJBydxHUJuQ0DeNNZTm

# %%
#url = "1QfbJBydxHUJuQ0DeNNZTm"

# %% [markdown]
# # Handling large playlists

# %%
# we will need more songs for our clustering
playlist = sp.user_playlist_tracks("spotify", "54nv8jbrm4JoHEZ49Qvjgl")

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
# this one is biiiig!
playlist["total"]
# Out:
# 9925

# %%
# Each page is limited to 100 tracks, we will have to fix it:
len(playlist["items"])
# Out:
# 100

# %%
# playlist['items'] contains the tracks on the playlist
playlist['items']
# Out:
# [{'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5BvgP623rtvlc0HDcpzquz'},
#     'href': 'https://api.spotify.com/v1/albums/5BvgP623rtvlc0HDcpzquz',
#     'id': '5BvgP623rtvlc0HDcpzquz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273937af329667311f4b2831616',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02937af329667311f4b2831616',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851937af329667311f4b2831616',
#       'width': 64}],
#     'name': 'Teenage Dream: The Complete Confection',
#     'release_date': '2012-03-12',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:5BvgP623rtvlc0HDcpzquz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#      'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#      'id': '6jJ0s89eD6GaHleKKya26X',
#      'name': 'Katy Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 227880,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA21001262'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4lCv7b86sLynZbXhfScfm2'},
#    'href': 'https://api.spotify.com/v1/tracks/4lCv7b86sLynZbXhfScfm2',
#    'id': '4lCv7b86sLynZbXhfScfm2',
#    'is_local': False,
#    'name': 'Firework',
#    'popularity': 72,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4lCv7b86sLynZbXhfScfm2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#       'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#       'id': '5Pwc4xIPtQLFEnJriah9YJ',
#       'name': 'OneRepublic',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#     'available_markets': ['CA', 'JP', 'MX', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2KSpGeDoNjqCKg6HL8LAyI'},
#     'href': 'https://api.spotify.com/v1/albums/2KSpGeDoNjqCKg6HL8LAyI',
#     'id': '2KSpGeDoNjqCKg6HL8LAyI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27334ef81d1ff3b4682a4e97f70',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0234ef81d1ff3b4682a4e97f70',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485134ef81d1ff3b4682a4e97f70',
#       'width': 64}],
#     'name': 'Dreaming Out Loud',
#     'release_date': '2007-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:2KSpGeDoNjqCKg6HL8LAyI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Pwc4xIPtQLFEnJriah9YJ'},
#      'href': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ',
#      'id': '5Pwc4xIPtQLFEnJriah9YJ',
#      'name': 'OneRepublic',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Pwc4xIPtQLFEnJriah9YJ'}],
#    'available_markets': ['CA', 'JP', 'MX', 'US'],
#    'disc_number': 1,
#    'duration_ms': 266226,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70758797'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1Jx69b09LKTuBQxkEiFfVX'},
#    'href': 'https://api.spotify.com/v1/tracks/1Jx69b09LKTuBQxkEiFfVX',
#    'id': '1Jx69b09LKTuBQxkEiFfVX',
#    'is_local': False,
#    'name': 'All We Are',
#    'popularity': 39,
#    'preview_url': None,
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:1Jx69b09LKTuBQxkEiFfVX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#       'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#       'id': '6Q192DXotxtaysaqNPy5yR',
#       'name': 'Amy Winehouse',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6GJCGWfI95aeRsdtVB52vc'},
#     'href': 'https://api.spotify.com/v1/albums/6GJCGWfI95aeRsdtVB52vc',
#     'id': '6GJCGWfI95aeRsdtVB52vc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734b6583b0a1505e40779faec6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024b6583b0a1505e40779faec6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514b6583b0a1505e40779faec6',
#       'width': 64}],
#     'name': 'Back To Black',
#     'release_date': '2006-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6GJCGWfI95aeRsdtVB52vc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Q192DXotxtaysaqNPy5yR'},
#      'href': 'https://api.spotify.com/v1/artists/6Q192DXotxtaysaqNPy5yR',
#      'id': '6Q192DXotxtaysaqNPy5yR',
#      'name': 'Amy Winehouse',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Q192DXotxtaysaqNPy5yR'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 221200,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM70603491'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4u83mwF5tUuWlXS86UOXdu'},
#    'href': 'https://api.spotify.com/v1/tracks/4u83mwF5tUuWlXS86UOXdu',
#    'id': '4u83mwF5tUuWlXS86UOXdu',
#    'is_local': False,
#    'name': 'Wake Up Alone',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:4u83mwF5tUuWlXS86UOXdu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#       'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#       'id': '3AQRLZ9PuTAozP28Skbq8V',
#       'name': 'The Script',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/51Hn2Wiq1jmUfI0BLaUhuF'},
#     'href': 'https://api.spotify.com/v1/albums/51Hn2Wiq1jmUfI0BLaUhuF',
#     'id': '51Hn2Wiq1jmUfI0BLaUhuF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b526ba531c80ed208cd428ed',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b526ba531c80ed208cd428ed',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b526ba531c80ed208cd428ed',
#       'width': 64}],
#     'name': 'The Script',
#     'release_date': '2008-09-08',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:51Hn2Wiq1jmUfI0BLaUhuF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#      'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#      'id': '3AQRLZ9PuTAozP28Skbq8V',
#      'name': 'The Script',
#      'type': 'artist',
#      'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 241466,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBARL0800144'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Musyaro0NM5Awx8b5c627'},
#    'href': 'https://api.spotify.com/v1/tracks/4Musyaro0NM5Awx8b5c627',
#    'id': '4Musyaro0NM5Awx8b5c627',
#    'is_local': False,
#    'name': "The Man Who Can't Be Moved",
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f57e04ec201a87cf73243b5279be7f5a5ee7678c?cid=55ae1815138c4eedb780d69965a64a36',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4Musyaro0NM5Awx8b5c627'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1azUkThwd2HfUDdeNeT147'},
#     'href': 'https://api.spotify.com/v1/albums/1azUkThwd2HfUDdeNeT147',
#     'id': '1azUkThwd2HfUDdeNeT147',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736d4056466fc11f6408be2566',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026d4056466fc11f6408be2566',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516d4056466fc11f6408be2566',
#       'width': 64}],
#     'name': '21',
#     'release_date': '2011-01-19',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:1azUkThwd2HfUDdeNeT147'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#      'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#      'id': '4dpARuHxo51G3z768sgnrY',
#      'name': 'Adele',
#      'type': 'artist',
#      'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 228293,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBKS1000335'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1CkvWZme3pRgbzaxZnTl5X'},
#    'href': 'https://api.spotify.com/v1/tracks/1CkvWZme3pRgbzaxZnTl5X',
#    'id': '1CkvWZme3pRgbzaxZnTl5X',
#    'is_local': False,
#    'name': 'Rolling in the Deep',
#    'popularity': 1,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1CkvWZme3pRgbzaxZnTl5X'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#       'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#       'id': '0du5cEVh5yTK9QJze8zA0C',
#       'name': 'Bruno Mars',
#       'type': 'artist',
#       'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#     'available_markets': ['AE',
#      'AG',
#      'AL',
#      'AR',
#      'AT',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GD',
#      'GR',
#      'GT',
#      'GY',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KN',
#      'KR',
#      'KW',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'NI',
#      'NL',
#      'NO',
#      'OM',
#      'PA',
#      'PE',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SR',
#      'SV',
#      'TN',
#      'TR',
#      'TT',
#      'UA',
#      'UY',
#      'VC',
#      'VE',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6J84szYCnMfzEcvIcfWMFL'},
#     'href': 'https://api.spotify.com/v1/albums/6J84szYCnMfzEcvIcfWMFL',
#     'id': '6J84szYCnMfzEcvIcfWMFL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f60070dce96a2c1b70cf6ff0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f60070dce96a2c1b70cf6ff0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f60070dce96a2c1b70cf6ff0',
#       'width': 64}],
#     'name': 'Doo-Wops & Hooligans',
#     'release_date': '2010-10-05',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6J84szYCnMfzEcvIcfWMFL'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#      'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#      'id': '0du5cEVh5yTK9QJze8zA0C',
#      'name': 'Bruno Mars',
#      'type': 'artist',
#      'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}],
#    'available_markets': ['AE',
#     'AG',
#     'AL',
#     'AR',
#     'AT',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BS',
#     'BZ',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GD',
#     'GR',
#     'GT',
#     'GY',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KN',
#     'KR',
#     'KW',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'NI',
#     'NL',
#     'NO',
#     'OM',
#     'PA',
#     'PE',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SR',
#     'SV',
#     'TN',
#     'TR',
#     'TT',
#     'UA',
#     'UY',
#     'VC',
#     'VE',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 222091,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21001883'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4lLtanYk6tkMvooU0tWzG8'},
#    'href': 'https://api.spotify.com/v1/tracks/4lLtanYk6tkMvooU0tWzG8',
#    'id': '4lLtanYk6tkMvooU0tWzG8',
#    'is_local': False,
#    'name': 'Grenade',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5221be592c832e14506f6304ff1deb6c52ae3fee?cid=55ae1815138c4eedb780d69965a64a36',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4lLtanYk6tkMvooU0tWzG8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4yHr095BMG5I3IRH4ToE5l'},
#     'href': 'https://api.spotify.com/v1/albums/4yHr095BMG5I3IRH4ToE5l',
#     'id': '4yHr095BMG5I3IRH4ToE5l',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ebb720684d839c8909d1dac3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ebb720684d839c8909d1dac3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ebb720684d839c8909d1dac3',
#       'width': 64}],
#     'name': 'The Fame Monster (Deluxe)',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 22,
#     'type': 'album',
#     'uri': 'spotify:album:4yHr095BMG5I3IRH4ToE5l'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 237213,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70824409'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3OT3Kg4jyVkdZm4Ncz6JgX'},
#    'href': 'https://api.spotify.com/v1/tracks/3OT3Kg4jyVkdZm4Ncz6JgX',
#    'id': '3OT3Kg4jyVkdZm4Ncz6JgX',
#    'is_local': False,
#    'name': 'Poker Face',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:3OT3Kg4jyVkdZm4Ncz6JgX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7H55rcKCfwqkyDFH9wpKM6'},
#       'href': 'https://api.spotify.com/v1/artists/7H55rcKCfwqkyDFH9wpKM6',
#       'id': '7H55rcKCfwqkyDFH9wpKM6',
#       'name': 'Christina Perri',
#       'type': 'artist',
#       'uri': 'spotify:artist:7H55rcKCfwqkyDFH9wpKM6'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'LI',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'KH',
#      'TD',
#      'SZ',
#      'KG',
#      'LA',
#      'MO',
#      'MN',
#      'NP',
#      'UZ',
#      'ZW',
#      'MU',
#      'MZ',
#      'TJ',
#      'VE',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3XNK8vPk3O1rjhDZyOMJ6n'},
#     'href': 'https://api.spotify.com/v1/albums/3XNK8vPk3O1rjhDZyOMJ6n',
#     'id': '3XNK8vPk3O1rjhDZyOMJ6n',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27326a2f5224465a369f8abbf88',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0226a2f5224465a369f8abbf88',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485126a2f5224465a369f8abbf88',
#       'width': 64}],
#     'name': 'lovestrong.',
#     'release_date': '2011-05-10',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:3XNK8vPk3O1rjhDZyOMJ6n'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7H55rcKCfwqkyDFH9wpKM6'},
#      'href': 'https://api.spotify.com/v1/artists/7H55rcKCfwqkyDFH9wpKM6',
#      'id': '7H55rcKCfwqkyDFH9wpKM6',
#      'name': 'Christina Perri',
#      'type': 'artist',
#      'uri': 'spotify:artist:7H55rcKCfwqkyDFH9wpKM6'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'LI',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'HT',
#     'JM',
#     'FM',
#     'NA',
#     'NE',
#     'PG',
#     'KN',
#     'LC',
#     'VC',
#     'TL',
#     'TT',
#     'AZ',
#     'BN',
#     'KH',
#     'TD',
#     'SZ',
#     'KG',
#     'LA',
#     'MO',
#     'MN',
#     'NP',
#     'UZ',
#     'ZW',
#     'MU',
#     'MZ',
#     'TJ',
#     'VE',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 233480,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21100501'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/21JTgoZLDB2F4Fx0uRCmTL'},
#    'href': 'https://api.spotify.com/v1/tracks/21JTgoZLDB2F4Fx0uRCmTL',
#    'id': '21JTgoZLDB2F4Fx0uRCmTL',
#    'is_local': False,
#    'name': 'the lonely',
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a2be20094c6e24a7477d357a4dfcdac0c17c4afe?cid=55ae1815138c4eedb780d69965a64a36',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:21JTgoZLDB2F4Fx0uRCmTL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#       'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#       'id': '4gzpq5DPGxSnKTe4SA8HAU',
#       'name': 'Coldplay',
#       'type': 'artist',
#       'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6ZG5lRT77aJ3btmArcykra'},
#     'href': 'https://api.spotify.com/v1/albums/6ZG5lRT77aJ3btmArcykra',
#     'id': '6ZG5lRT77aJ3btmArcykra',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733d92b2ad5af9fbc8637425f0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023d92b2ad5af9fbc8637425f0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513d92b2ad5af9fbc8637425f0',
#       'width': 64}],
#     'name': 'Parachutes',
#     'release_date': '2000-07-10',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6ZG5lRT77aJ3btmArcykra'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzpq5DPGxSnKTe4SA8HAU'},
#      'href': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU',
#      'id': '4gzpq5DPGxSnKTe4SA8HAU',
#      'name': 'Coldplay',
#      'type': 'artist',
#      'uri': 'spotify:artist:4gzpq5DPGxSnKTe4SA8HAU'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 266773,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE0000267'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3AJwUDP919kvQ9QcozQPxg'},
#    'href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg',
#    'id': '3AJwUDP919kvQ9QcozQPxg',
#    'is_local': False,
#    'name': 'Yellow',
#    'popularity': 91,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c0d9119dc69cae75baf6463e21e43f433fdf5ff4?cid=55ae1815138c4eedb780d69965a64a36',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Sqr0DXoaYABbjBo9HaMkM'},
#       'href': 'https://api.spotify.com/v1/artists/2Sqr0DXoaYABbjBo9HaMkM',
#       'id': '2Sqr0DXoaYABbjBo9HaMkM',
#       'name': 'Sara Bareilles',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Sqr0DXoaYABbjBo9HaMkM'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Z9WUERfMjOgQ6ze9TcGbF'},
#     'href': 'https://api.spotify.com/v1/albums/2Z9WUERfMjOgQ6ze9TcGbF',
#     'id': '2Z9WUERfMjOgQ6ze9TcGbF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731c3e0a58f3ee28af2922e351',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021c3e0a58f3ee28af2922e351',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511c3e0a58f3ee28af2922e351',
#       'width': 64}],
#     'name': 'Little Voice',
#     'release_date': '2007-07-03',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2Z9WUERfMjOgQ6ze9TcGbF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Sqr0DXoaYABbjBo9HaMkM'},
#      'href': 'https://api.spotify.com/v1/artists/2Sqr0DXoaYABbjBo9HaMkM',
#      'id': '2Sqr0DXoaYABbjBo9HaMkM',
#      'name': 'Sara Bareilles',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Sqr0DXoaYABbjBo9HaMkM'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 232760,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10700068'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4oa14QBfWRDfJy2agySy0L'},
#    'href': 'https://api.spotify.com/v1/tracks/4oa14QBfWRDfJy2agySy0L',
#    'id': '4oa14QBfWRDfJy2agySy0L',
#    'is_local': False,
#    'name': 'Gravity',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b1bf479b4eddb35aa086e226080cc0202188a337?cid=55ae1815138c4eedb780d69965a64a36',
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:4oa14QBfWRDfJy2agySy0L'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#       'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#       'id': '3BmGtnKgCSGYIUhmivXKWX',
#       'name': 'Kelly Clarkson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0VmE95pr5TSpZWucfyhO5e'},
#     'href': 'https://api.spotify.com/v1/albums/0VmE95pr5TSpZWucfyhO5e',
#     'id': '0VmE95pr5TSpZWucfyhO5e',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273af384269742c6b04308c1be8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02af384269742c6b04308c1be8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851af384269742c6b04308c1be8',
#       'width': 64}],
#     'name': 'Stronger (Deluxe Version)',
# ...
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Kx7MNY7cI1ENniW7vT30N'},
#      'href': 'https://api.spotify.com/v1/artists/2Kx7MNY7cI1ENniW7vT30N',
#      'id': '2Kx7MNY7cI1ENniW7vT30N',
#      'name': 'Norah Jones',
#      'type': 'artist',
#      'uri': 'spotify:artist:2Kx7MNY7cI1ENniW7vT30N'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 186146,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USBN20100529'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ybViy2qrO9sIi41EgRJgx'},
#    'href': 'https://api.spotify.com/v1/tracks/6ybViy2qrO9sIi41EgRJgx',
#    'id': '6ybViy2qrO9sIi41EgRJgx',
#    'is_local': False,
#    'name': "Don't Know Why",
#    'popularity': 15,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6ybViy2qrO9sIi41EgRJgx'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zzrJD2jXrE9dZ1AklRFcL'},
#       'href': 'https://api.spotify.com/v1/artists/5zzrJD2jXrE9dZ1AklRFcL',
#       'id': '5zzrJD2jXrE9dZ1AklRFcL',
#       'name': 'KT Tunstall',
#       'type': 'artist',
#       'uri': 'spotify:artist:5zzrJD2jXrE9dZ1AklRFcL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3j70PDKieTWQAwas3bPHRZ'},
#     'href': 'https://api.spotify.com/v1/albums/3j70PDKieTWQAwas3bPHRZ',
#     'id': '3j70PDKieTWQAwas3bPHRZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273183730e8038fa632b2c227da',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02183730e8038fa632b2c227da',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851183730e8038fa632b2c227da',
#       'width': 64}],
#     'name': 'Eye To The Telescope',
#     'release_date': '2005-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3j70PDKieTWQAwas3bPHRZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5zzrJD2jXrE9dZ1AklRFcL'},
#      'href': 'https://api.spotify.com/v1/artists/5zzrJD2jXrE9dZ1AklRFcL',
#      'id': '5zzrJD2jXrE9dZ1AklRFcL',
#      'name': 'KT Tunstall',
#      'type': 'artist',
#      'uri': 'spotify:artist:5zzrJD2jXrE9dZ1AklRFcL'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 172373,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBGLM0400102'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0qAMjeQFyd1qD0LDiV8gWp'},
#    'href': 'https://api.spotify.com/v1/tracks/0qAMjeQFyd1qD0LDiV8gWp',
#    'id': '0qAMjeQFyd1qD0LDiV8gWp',
#    'is_local': False,
#    'name': 'Black Horse And The Cherry Tree',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:0qAMjeQFyd1qD0LDiV8gWp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1gIC63gC3B7o7FfpPACZQJ'},
#     'href': 'https://api.spotify.com/v1/albums/1gIC63gC3B7o7FfpPACZQJ',
#     'id': '1gIC63gC3B7o7FfpPACZQJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ff5429125128b43572dbdccd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ff5429125128b43572dbdccd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ff5429125128b43572dbdccd',
#       'width': 64}],
#     'name': '4',
#     'release_date': '2011-06-24',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1gIC63gC3B7o7FfpPACZQJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#      'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#      'id': '6vWDO969PvNqNYHIOW5v0m',
#      'name': 'Beyoncé',
#      'type': 'artist',
#      'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 212146,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM11102909'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3axkNosdVQLZiq1HakuGhc'},
#    'href': 'https://api.spotify.com/v1/tracks/3axkNosdVQLZiq1HakuGhc',
#    'id': '3axkNosdVQLZiq1HakuGhc',
#    'is_local': False,
#    'name': 'Countdown',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e2e035120822d8a554cb7a836a8f413d8a9d5d2b?cid=55ae1815138c4eedb780d69965a64a36',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3axkNosdVQLZiq1HakuGhc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2015-12-22T02:52:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/thedoctorkto'},
#    'href': 'https://api.spotify.com/v1/users/thedoctorkto',
#    'id': 'thedoctorkto',
#    'type': 'user',
#    'uri': 'spotify:user:thedoctorkto'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1G2ZRwcqN6warfakvcPgEs'},
#     'href': 'https://api.spotify.com/v1/albums/1G2ZRwcqN6warfakvcPgEs',
#     'id': '1G2ZRwcqN6warfakvcPgEs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ad4ef80be7f5e15d64ac5c25',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ad4ef80be7f5e15d64ac5c25',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ad4ef80be7f5e15d64ac5c25',
#       'width': 64}],
#     'name': 'Good Girl Gone Bad: Reloaded',
#     'release_date': '2008-06-02',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:1G2ZRwcqN6warfakvcPgEs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#      'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#      'id': '5pKCCKE2ajJHZ9KAiaK11H',
#      'name': 'Rihanna',
#      'type': 'artist',
#      'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 267080,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70734700'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6tXjP6xgPJ7Xr1igrO6bOE'},
#    'href': 'https://api.spotify.com/v1/tracks/6tXjP6xgPJ7Xr1igrO6bOE',
#    'id': '6tXjP6xgPJ7Xr1igrO6bOE',
#    'is_local': False,
#    'name': "Don't Stop The Music",
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6tXjP6xgPJ7Xr1igrO6bOE'},
#   'video_thumbnail': {'url': None}}]

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("54nv8jbrm4JoHEZ49Qvjgl")
len(all_tracks)
# Out:
# 9925

# %%
import pandas as pd
from pandas import json_normalize

# %%
tracks_playlist1_normalized = json_normalize(all_tracks)

# %%
print(tracks_playlist1_normalized.shape)
tracks_playlist1_normalized
# Out:
# (9925, 41)
#                   added_at  is_local primary_color  \
# 0     2015-12-22T02:52:05Z     False          None
# 1     2015-12-22T02:52:05Z     False          None
# 2     2015-12-22T02:52:05Z     False          None
# 3     2015-12-22T02:52:05Z     False          None
# 4     2015-12-22T02:52:05Z     False          None
# ...                    ...       ...           ...
# 9920  2021-11-19T17:36:06Z     False          None
# 9921  2021-12-01T17:35:38Z     False          None
# 9922  2021-12-06T15:34:26Z     False          None
# 9923  2021-12-06T19:57:48Z     False          None
# 9924  2021-12-07T16:32:08Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0     https://open.spotify.com/user/thedoctorkto
# 1     https://open.spotify.com/user/thedoctorkto
# 2     https://open.spotify.com/user/thedoctorkto
# 3     https://open.spotify.com/user/thedoctorkto
# 4     https://open.spotify.com/user/thedoctorkto
# ...                                          ...
# 9920  https://open.spotify.com/user/thedoctorkto
# 9921  https://open.spotify.com/user/thedoctorkto
# 9922  https://open.spotify.com/user/thedoctorkto
# 9923  https://open.spotify.com/user/thedoctorkto
# 9924  https://open.spotify.com/user/thedoctorkto
#
#                                       added_by.href   added_by.id  \
# 0     https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# 1     https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# 2     https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# 3     https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# 4     https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# ...                                             ...           ...
# 9920  https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# 9921  https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# 9922  https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# 9923  https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
# 9924  https://api.spotify.com/v1/users/thedoctorkto  thedoctorkto
#
#      added_by.type               added_by.uri track.album.album_type  \
# 0             user  spotify:user:thedoctorkto                  album
# 1             user  spotify:user:thedoctorkto                  album
# 2             user  spotify:user:thedoctorkto                  album
# 3             user  spotify:user:thedoctorkto                  album
# 4             user  spotify:user:thedoctorkto                  album
# ...            ...                        ...                    ...
# 9920          user  spotify:user:thedoctorkto                 single
# 9921          user  spotify:user:thedoctorkto                  album
# 9922          user  spotify:user:thedoctorkto                  album
# 9923          user  spotify:user:thedoctorkto                  album
# 9924          user  spotify:user:thedoctorkto                 single
#
#                                     track.album.artists  ... track.is_local  \
# 0     [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 1     [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 2     [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 3     [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 4     [{'external_urls': {'spotify': 'https://open.s...  ...          False
# ...                                                 ...  ...            ...
# 9920  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 9921  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 9922  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 9923  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 9924  [{'external_urls': {'spotify': 'https://open.s...  ...          False
#
#                       track.name track.popularity  \
# 0                       Firework             72.0
# 1                     All We Are             39.0
# 2                  Wake Up Alone              0.0
# 3     The Man Who Can't Be Moved             56.0
# 4            Rolling in the Deep              1.0
# ...                          ...              ...
# 9920                  I AM WOMAN             71.0
# 9921                    The Girl             56.0
# 9922                 The Funeral             74.0
# 9923             Hallucinogenics             72.0
# 9924                      Brazil             61.0
#
#                                       track.preview_url track.track  \
# 0                                                  None        True
# 1                                                  None        True
# 2                                                  None        True
# 3     https://p.scdn.co/mp3-preview/f57e04ec201a87cf...        True
# 4                                                  None        True
# ...                                                 ...         ...
# 9920  https://p.scdn.co/mp3-preview/9854e9bedbfa0a5a...        True
# 9921  https://p.scdn.co/mp3-preview/a892377e06ebb163...        True
# 9922  https://p.scdn.co/mp3-preview/a3d4810ce9c8ea87...        True
# 9923  https://p.scdn.co/mp3-preview/aa52075bc5c4f19d...        True
# 9924  https://p.scdn.co/mp3-preview/819af1665fb4b2a1...        True
#
#      track.track_number track.type                             track.uri  \
# 0                   4.0      track  spotify:track:4lCv7b86sLynZbXhfScfm2
# 1                  10.0      track  spotify:track:1Jx69b09LKTuBQxkEiFfVX
# 2                   8.0      track  spotify:track:4u83mwF5tUuWlXS86UOXdu
# 3                   4.0      track  spotify:track:4Musyaro0NM5Awx8b5c627
# 4                   1.0      track  spotify:track:1CkvWZme3pRgbzaxZnTl5X
# ...                 ...        ...                                   ...
# 9920                1.0      track  spotify:track:3nOz1U41SZZ0N3fuUWr9nb
# 9921               10.0      track  spotify:track:1IFRVS4t1olI0XG9RBWdKH
# 9922                4.0      track  spotify:track:5lRzWDEe7UuedU2QPsFg0K
# 9923                6.0      track  spotify:track:6bLU8e0LGyztE9iD5DWBQ1
# 9924                1.0      track  spotify:track:5ftdTvmQjjsL23t7jxADfI
#
#       video_thumbnail.url track
# 0                    None   NaN
# 1                    None   NaN
# 2                    None   NaN
# 3                    None   NaN
# 4                    None   NaN
# ...                   ...   ...
# 9920                 None   NaN
# 9921                 None   NaN
# 9922                 None   NaN
# 9923                 None   NaN
# 9924                 None   NaN
#
# [9925 rows x 41 columns]

# %%
 #Here the code to only choose the dictionaries and not the lists:

def expand_list_dict2(row):
    artists_data = row['track.artists']
    if isinstance(artists_data, list):
        artists_data = [artist for artist in artists_data if isinstance(artist, dict)]
        if artists_data:
            df = json_normalize(artists_data)
            df['song_id'] = row['track.id']
            return df
    return None


tracks_playlist1_normalized['artists_dfs'] = tracks_playlist1_normalized.apply(expand_list_dict2, axis=1)
tracks_playlist1_normalized['artists_dfs'][2]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6Q192DXotxt...  6Q192DXotxtaysaqNPy5yR
#
#             name    type                                    uri  \
# 0  Amy Winehouse  artist  spotify:artist:6Q192DXotxtaysaqNPy5yR
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/6Q192DXotxtays...  4u83mwF5tUuWlXS86UOXdu

# %% [markdown]
# For clustering our songs we will need:
#    - title of the song
#    - artist(s) of the song
#    - the song's audio features, which we can find through its id
#
# So the first step is to create a DataFrame with song title, artist name and song id.<br>
# Some songs have multiple artists, and we want to have a row for each artist with that song and id.

# %%
# a list of dict is less easy to handle than a dict of dicts, so we create that insted
#def list_to_dict(x):
    #return {i: x[i] for i in range(len(x))}

# %%
########################################

# %%
#def list_to_dict(x):
    #if isinstance(x, list):
        #return {i: x[i] for i in range(len(x))}
    #elif isinstance(x, dict):
        #return x
    #else:
        #return {}

# %%
#def expand_list_dict2(row):
    #df = pd.DataFrame.from_dict(row['artist_dict'], orient='index')
    #df['song_id'] = row['track.id']
    #return df

#tracks_playlist1['artists_dfs'] = tracks_playlist1.apply(expand_list_dict2, axis=1)

# %%
########################################

# %%
# Here we say: if there is lists inside, please only select the ones that are dictionaries in our defined artists_data and then apply
# the normalization only in the dictionaries. Because the lists are empty.

# %%
#import pandas as pd
#from pandas import json_normalize
#from pandas.core.apply import frame_apply

# Alternative Code which should lead to the same result, function to expand tracks_playlist1:
#def expand_list_dict2(row):
    #df = json_normalize(row['track.artists'])
    #df['song_id'] = row['track.id']
    #return df

#tracks_playlist1['artists_dfs'] = tracks_playlist1.apply(expand_list_dict2, axis=1)
#tracks2['artists_dfs'][0]

# %%
# now we create a new dataframe with all these artists
artist_df1 = pd.DataFrame(columns=['external_urls', 'href', 'id', 'name', 'type', 'uri'])
for val in tracks_playlist1_normalized['artists_dfs']:
    #display(val)
    artist_df1 = pd.concat([artist_df1, val], axis=0)
    
artist_df1
# Out:
#    external_urls                                               href  \
# 0            NaN  https://api.spotify.com/v1/artists/6jJ0s89eD6G...
# 0            NaN  https://api.spotify.com/v1/artists/5Pwc4xIPtQL...
# 0            NaN  https://api.spotify.com/v1/artists/6Q192DXotxt...
# 0            NaN  https://api.spotify.com/v1/artists/3AQRLZ9PuTA...
# 0            NaN  https://api.spotify.com/v1/artists/4dpARuHxo51...
# ..           ...                                                ...
# 0            NaN  https://api.spotify.com/v1/artists/71szvmFWd7T...
# 0            NaN  https://api.spotify.com/v1/artists/74gcBzlQza1...
# 0            NaN  https://api.spotify.com/v1/artists/0OdUWJ0sBjD...
# 0            NaN  https://api.spotify.com/v1/artists/7gHscNMDI8F...
# 0            NaN  https://api.spotify.com/v1/artists/2D4FOOOtWyc...
#
#                         id             name    type  \
# 0   6jJ0s89eD6GaHleKKya26X       Katy Perry  artist
# 0   5Pwc4xIPtQLFEnJriah9YJ      OneRepublic  artist
# 0   6Q192DXotxtaysaqNPy5yR    Amy Winehouse  artist
# 0   3AQRLZ9PuTAozP28Skbq8V       The Script  artist
# 0   4dpARuHxo51G3z768sgnrY            Adele  artist
# ..                     ...              ...     ...
# 0   71szvmFWd7TUa7b6XmXj9k        Emmy Meli  artist
# 0   74gcBzlQza1bSfob90yRhR  City and Colour  artist
# 0   0OdUWJ0sBjDrqHygGUXeCF   Band of Horses  artist
# 0   7gHscNMDI8FF8pcgrV8eIn      Matt Maeson  artist
# 0   2D4FOOOtWycb3Aw9nY5n3c   Declan McKenna  artist
#
#                                       uri  \
# 0   spotify:artist:6jJ0s89eD6GaHleKKya26X
# 0   spotify:artist:5Pwc4xIPtQLFEnJriah9YJ
# 0   spotify:artist:6Q192DXotxtaysaqNPy5yR
# 0   spotify:artist:3AQRLZ9PuTAozP28Skbq8V
# 0   spotify:artist:4dpARuHxo51G3z768sgnrY
# ..                                    ...
# 0   spotify:artist:71szvmFWd7TUa7b6XmXj9k
# 0   spotify:artist:74gcBzlQza1bSfob90yRhR
# 0   spotify:artist:0OdUWJ0sBjDrqHygGUXeCF
# 0   spotify:artist:7gHscNMDI8FF8pcgrV8eIn
# 0   spotify:artist:2D4FOOOtWycb3Aw9nY5n3c
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/6jJ0s89eD6GaHl...  4lCv7b86sLynZbXhfScfm2
# 0   https://open.spotify.com/artist/5Pwc4xIPtQLFEn...  1Jx69b09LKTuBQxkEiFfVX
# 0   https://open.spotify.com/artist/6Q192DXotxtays...  4u83mwF5tUuWlXS86UOXdu
# 0   https://open.spotify.com/artist/3AQRLZ9PuTAozP...  4Musyaro0NM5Awx8b5c627
# 0   https://open.spotify.com/artist/4dpARuHxo51G3z...  1CkvWZme3pRgbzaxZnTl5X
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/71szvmFWd7TUa7...  3nOz1U41SZZ0N3fuUWr9nb
# 0   https://open.spotify.com/artist/74gcBzlQza1bSf...  1IFRVS4t1olI0XG9RBWdKH
# 0   https://open.spotify.com/artist/0OdUWJ0sBjDrqH...  5lRzWDEe7UuedU2QPsFg0K
# 0   https://open.spotify.com/artist/7gHscNMDI8FF8p...  6bLU8e0LGyztE9iD5DWBQ1
# 0   https://open.spotify.com/artist/2D4FOOOtWycb3A...  5ftdTvmQjjsL23t7jxADfI
#
# [12188 rows x 8 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged1 = pd.merge(left=tracks_playlist1_normalized,
                    right=artist_df1,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_final1 = df_merged1[['track.name', 'name', 'song_id']]
df_final1
# Out:
#                        track.name             name                 song_id
# 0                        Firework       Katy Perry  4lCv7b86sLynZbXhfScfm2
# 1                      All We Are      OneRepublic  1Jx69b09LKTuBQxkEiFfVX
# 2                   Wake Up Alone    Amy Winehouse  4u83mwF5tUuWlXS86UOXdu
# 3      The Man Who Can't Be Moved       The Script  4Musyaro0NM5Awx8b5c627
# 4             Rolling in the Deep            Adele  1CkvWZme3pRgbzaxZnTl5X
# ...                           ...              ...                     ...
# 12235                  I AM WOMAN        Emmy Meli  3nOz1U41SZZ0N3fuUWr9nb
# 12236                    The Girl  City and Colour  1IFRVS4t1olI0XG9RBWdKH
# 12237                 The Funeral   Band of Horses  5lRzWDEe7UuedU2QPsFg0K
# 12238             Hallucinogenics      Matt Maeson  6bLU8e0LGyztE9iD5DWBQ1
# 12239                      Brazil   Declan McKenna  5ftdTvmQjjsL23t7jxADfI
#
# [12240 rows x 3 columns]

# %%
df_final_1 = df_merged1[['track.name', 'name', 'song_id']]
df_final_1
# Out:
#                        track.name             name                 song_id
# 0                        Firework       Katy Perry  4lCv7b86sLynZbXhfScfm2
# 1                      All We Are      OneRepublic  1Jx69b09LKTuBQxkEiFfVX
# 2                   Wake Up Alone    Amy Winehouse  4u83mwF5tUuWlXS86UOXdu
# 3      The Man Who Can't Be Moved       The Script  4Musyaro0NM5Awx8b5c627
# 4             Rolling in the Deep            Adele  1CkvWZme3pRgbzaxZnTl5X
# ...                           ...              ...                     ...
# 12235                  I AM WOMAN        Emmy Meli  3nOz1U41SZZ0N3fuUWr9nb
# 12236                    The Girl  City and Colour  1IFRVS4t1olI0XG9RBWdKH
# 12237                 The Funeral   Band of Horses  5lRzWDEe7UuedU2QPsFg0K
# 12238             Hallucinogenics      Matt Maeson  6bLU8e0LGyztE9iD5DWBQ1
# 12239                      Brazil   Declan McKenna  5ftdTvmQjjsL23t7jxADfI
#
# [12240 rows x 3 columns]

# %%
# probably let them figure this out in the lab :-) # Getting the audio data
chunks = [(i, i+100) for i in range(0, len(df_final_1), 100)]
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final_1['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 12240

# %%
audio_features_df = json_normalize(audio_features_list)

# %%
audio_features_df.drop_duplicates(inplace=True)

# %%
df_w_audio_ft = pd.merge(left=df_final_1,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft
# Out:
#                        track.name             name                 song_id  \
# 0                        Firework       Katy Perry  4lCv7b86sLynZbXhfScfm2
# 1                      All We Are      OneRepublic  1Jx69b09LKTuBQxkEiFfVX
# 2                   Wake Up Alone    Amy Winehouse  4u83mwF5tUuWlXS86UOXdu
# 3      The Man Who Can't Be Moved       The Script  4Musyaro0NM5Awx8b5c627
# 4             Rolling in the Deep            Adele  1CkvWZme3pRgbzaxZnTl5X
# ...                           ...              ...                     ...
# 12235                  I AM WOMAN        Emmy Meli  3nOz1U41SZZ0N3fuUWr9nb
# 12236                    The Girl  City and Colour  1IFRVS4t1olI0XG9RBWdKH
# 12237                 The Funeral   Band of Horses  5lRzWDEe7UuedU2QPsFg0K
# 12238             Hallucinogenics      Matt Maeson  6bLU8e0LGyztE9iD5DWBQ1
# 12239                      Brazil   Declan McKenna  5ftdTvmQjjsL23t7jxADfI
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.638   0.826    8    -4.968     1       0.0479        0.1390
# 1             0.397   0.817    2    -5.495     1       0.0420        0.0966
# 2             0.384   0.527   11    -5.294     0       0.0269        0.5420
# 3             0.608   0.629   10    -5.024     1       0.0264        0.4230
# 4             0.729   0.756    8    -5.119     1       0.0294        0.1310
# ...             ...     ...  ...       ...   ...          ...           ...
# 12235         0.646   0.471   10    -9.247     1       0.1570        0.1220
# 12236         0.404   0.542   10    -7.578     1       0.0349        0.8370
# 12237         0.319   0.757    0    -6.117     0       0.0432        0.0160
# 12238         0.549   0.653    0    -7.470     1       0.0503        0.4570
# 12239         0.689   0.617    4    -5.196     1       0.0290        0.0918
#
#        ...  liveness  valence    tempo            type  \
# 0      ...    0.0803    0.649  124.072  audio_features
# 1      ...    0.3160    0.416  158.004  audio_features
# 2      ...    0.1560    0.222  100.730  audio_features
# 3      ...    0.0978    0.325   99.953  audio_features
# 4      ...    0.0527    0.522  104.945  audio_features
# ...    ...       ...      ...      ...             ...
# 12235  ...    0.1250    0.455  170.084  audio_features
# 12236  ...    0.1370    0.183  109.166  audio_features
# 12237  ...    0.1020    0.101  122.465  audio_features
# 12238  ...    0.0969    0.287  121.348  audio_features
# 12239  ...    0.0816    0.682  121.062  audio_features
#
#                            id                                   uri  \
# 0      4lCv7b86sLynZbXhfScfm2  spotify:track:4lCv7b86sLynZbXhfScfm2
# 1      1Jx69b09LKTuBQxkEiFfVX  spotify:track:1Jx69b09LKTuBQxkEiFfVX
# 2      4u83mwF5tUuWlXS86UOXdu  spotify:track:4u83mwF5tUuWlXS86UOXdu
# 3      4Musyaro0NM5Awx8b5c627  spotify:track:4Musyaro0NM5Awx8b5c627
# 4      1CkvWZme3pRgbzaxZnTl5X  spotify:track:1CkvWZme3pRgbzaxZnTl5X
# ...                       ...                                   ...
# 12235  3nOz1U41SZZ0N3fuUWr9nb  spotify:track:3nOz1U41SZZ0N3fuUWr9nb
# 12236  1IFRVS4t1olI0XG9RBWdKH  spotify:track:1IFRVS4t1olI0XG9RBWdKH
# 12237  5lRzWDEe7UuedU2QPsFg0K  spotify:track:5lRzWDEe7UuedU2QPsFg0K
# 12238  6bLU8e0LGyztE9iD5DWBQ1  spotify:track:6bLU8e0LGyztE9iD5DWBQ1
# 12239  5ftdTvmQjjsL23t7jxADfI  spotify:track:5ftdTvmQjjsL23t7jxADfI
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/4lCv7b86sLyn...
# 1      https://api.spotify.com/v1/tracks/1Jx69b09LKTu...
# 2      https://api.spotify.com/v1/tracks/4u83mwF5tUuW...
# 3      https://api.spotify.com/v1/tracks/4Musyaro0NM5...
# 4      https://api.spotify.com/v1/tracks/1CkvWZme3pRg...
# ...                                                  ...
# 12235  https://api.spotify.com/v1/tracks/3nOz1U41SZZ0...
# 12236  https://api.spotify.com/v1/tracks/1IFRVS4t1olI...
# 12237  https://api.spotify.com/v1/tracks/5lRzWDEe7Uue...
# 12238  https://api.spotify.com/v1/tracks/6bLU8e0LGyzt...
# 12239  https://api.spotify.com/v1/tracks/5ftdTvmQjjsL...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/4lCv...      227880
# 1      https://api.spotify.com/v1/audio-analysis/1Jx6...      266227
# 2      https://api.spotify.com/v1/audio-analysis/4u83...      221200
# 3      https://api.spotify.com/v1/audio-analysis/4Mus...      241467
# 4      https://api.spotify.com/v1/audio-analysis/1Ckv...      228293
# ...                                                  ...         ...
# 12235  https://api.spotify.com/v1/audio-analysis/3nOz...      232813
# 12236  https://api.spotify.com/v1/audio-analysis/1IFR...      360107
# 12237  https://api.spotify.com/v1/audio-analysis/5lRz...      322173
# 12238  https://api.spotify.com/v1/audio-analysis/6bLU...      187173
# 12239  https://api.spotify.com/v1/audio-analysis/5ftd...      252307
#
#        time_signature
# 0                   4
# 1                   4
# 2                   3
# 3                   4
# 4                   4
# ...               ...
# 12235               4
# 12236               4
# 12237               4
# 12238               4
# 12239               4
#
# [12240 rows x 21 columns]

# %% [markdown]
# 2. Playlist https://open.spotify.com/playlist/5zM1HJ9E3eNw3AdjG4qv9X

# %%
# we will need more songs for our clustering
playlist = sp.user_playlist_tracks("spotify", "5zM1HJ9E3eNw3AdjG4qv9X")

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
# this one is biiiig!
playlist["total"]
# Out:
# 4211

# %%
# playlist['items'] contains the tracks on the playlist
playlist['items']
# Out:
# [{'added_at': '2019-01-03T17:56:15Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kXp61QMZFPcKMcRPqoiVj'},
#       'href': 'https://api.spotify.com/v1/artists/6kXp61QMZFPcKMcRPqoiVj',
#       'id': '6kXp61QMZFPcKMcRPqoiVj',
#       'name': 'Gin Blossoms',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kXp61QMZFPcKMcRPqoiVj'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/484pzryEPqn6KSMLtP2c4f'},
#     'href': 'https://api.spotify.com/v1/albums/484pzryEPqn6KSMLtP2c4f',
#     'id': '484pzryEPqn6KSMLtP2c4f',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e3100bdcdc758b5fab7e4894',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e3100bdcdc758b5fab7e4894',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e3100bdcdc758b5fab7e4894',
#       'width': 64}],
#     'name': 'New Miserable Experience',
#     'release_date': '1992-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:484pzryEPqn6KSMLtP2c4f'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kXp61QMZFPcKMcRPqoiVj'},
#      'href': 'https://api.spotify.com/v1/artists/6kXp61QMZFPcKMcRPqoiVj',
#      'id': '6kXp61QMZFPcKMcRPqoiVj',
#      'name': 'Gin Blossoms',
#      'type': 'artist',
#      'uri': 'spotify:artist:6kXp61QMZFPcKMcRPqoiVj'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 236626,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAM19201246'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4o7ZPI2fmEi3piRe0Hrfpy'},
#    'href': 'https://api.spotify.com/v1/tracks/4o7ZPI2fmEi3piRe0Hrfpy',
#    'id': '4o7ZPI2fmEi3piRe0Hrfpy',
#    'is_local': False,
#    'name': 'Hey Jealousy',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4o7ZPI2fmEi3piRe0Hrfpy'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T17:56:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7guDJrEfX3qb6FEbdPA5qi'},
#       'href': 'https://api.spotify.com/v1/artists/7guDJrEfX3qb6FEbdPA5qi',
#       'id': '7guDJrEfX3qb6FEbdPA5qi',
#       'name': 'Stevie Wonder',
#       'type': 'artist',
#       'uri': 'spotify:artist:7guDJrEfX3qb6FEbdPA5qi'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7fjiLZzAXNUXUazn89VBMc'},
#     'href': 'https://api.spotify.com/v1/albums/7fjiLZzAXNUXUazn89VBMc',
#     'id': '7fjiLZzAXNUXUazn89VBMc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27362ca35eb62bb4a3743b2b405',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0262ca35eb62bb4a3743b2b405',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485162ca35eb62bb4a3743b2b405',
#       'width': 64}],
#     'name': 'The Definitive Collection',
#     'release_date': '2002',
#     'release_date_precision': 'year',
#     'total_tracks': 21,
#     'type': 'album',
#     'uri': 'spotify:album:7fjiLZzAXNUXUazn89VBMc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7guDJrEfX3qb6FEbdPA5qi'},
#      'href': 'https://api.spotify.com/v1/artists/7guDJrEfX3qb6FEbdPA5qi',
#      'id': '7guDJrEfX3qb6FEbdPA5qi',
#      'name': 'Stevie Wonder',
#      'type': 'artist',
#      'uri': 'spotify:artist:7guDJrEfX3qb6FEbdPA5qi'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 245493,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMO10000310'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Y8i6ntDzXIhCO4UJPl5Qv'},
#    'href': 'https://api.spotify.com/v1/tracks/2Y8i6ntDzXIhCO4UJPl5Qv',
#    'id': '2Y8i6ntDzXIhCO4UJPl5Qv',
#    'is_local': False,
#    'name': 'Superstition - Single Version',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:2Y8i6ntDzXIhCO4UJPl5Qv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T17:56:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#       'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#       'id': '5a2EaR3hamoenG9rDuVn8j',
#       'name': 'Prince',
#       'type': 'artist',
#       'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/54DjkEN3wdCQgfCTZ9WjdB'},
#     'href': 'https://api.spotify.com/v1/albums/54DjkEN3wdCQgfCTZ9WjdB',
#     'id': '54DjkEN3wdCQgfCTZ9WjdB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27323cc0f0a925845a3de4aca38',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0223cc0f0a925845a3de4aca38',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485123cc0f0a925845a3de4aca38',
#       'width': 64}],
#     'name': 'Parade - Music from the Motion Picture Under the Cherry Moon',
#     'release_date': '1986-03-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:54DjkEN3wdCQgfCTZ9WjdB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5a2EaR3hamoenG9rDuVn8j'},
#      'href': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j',
#      'id': '5a2EaR3hamoenG9rDuVn8j',
#      'name': 'Prince',
#      'type': 'artist',
#      'uri': 'spotify:artist:5a2EaR3hamoenG9rDuVn8j'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'HT',
#     'JM',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'FM',
#     'NA',
#     'NE',
#     'PG',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'KN',
#     'LC',
#     'VC',
#     'TL',
#     'TT',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 226240,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB19903319'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/62LJFaYihsdVrrkgUOJC05'},
#    'href': 'https://api.spotify.com/v1/tracks/62LJFaYihsdVrrkgUOJC05',
#    'id': '62LJFaYihsdVrrkgUOJC05',
#    'is_local': False,
#    'name': 'Kiss',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/390cf478a1f3fbdcf7b5346a6004d273ed47ed3f?cid=55ae1815138c4eedb780d69965a64a36',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:62LJFaYihsdVrrkgUOJC05'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T17:59:08Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#       'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#       'id': '2RdwBSPQiwcmiDo9kixcl8',
#       'name': 'Pharrell Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2lkQd5T32QHDOfFkEIPJKz'},
#     'href': 'https://api.spotify.com/v1/albums/2lkQd5T32QHDOfFkEIPJKz',
#     'id': '2lkQd5T32QHDOfFkEIPJKz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d005b5fa12875efb624e8e12',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d005b5fa12875efb624e8e12',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d005b5fa12875efb624e8e12',
#       'width': 64}],
#     'name': 'G I R L',
#     'release_date': '2014-03-03',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:2lkQd5T32QHDOfFkEIPJKz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#      'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#      'id': '2RdwBSPQiwcmiDo9kixcl8',
#      'name': 'Pharrell Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 232720,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USQ4E1300686'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5b88tNINg4Q4nrRbrCXUmg'},
#    'href': 'https://api.spotify.com/v1/tracks/5b88tNINg4Q4nrRbrCXUmg',
#    'id': '5b88tNINg4Q4nrRbrCXUmg',
#    'is_local': False,
#    'name': 'Happy - From "Despicable Me 2"',
#    'popularity': 4,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5b88tNINg4Q4nrRbrCXUmg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T17:59:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sD1ZLf2dGQ9gQ3YJl1eAd'},
#       'href': 'https://api.spotify.com/v1/artists/5sD1ZLf2dGQ9gQ3YJl1eAd',
#       'id': '5sD1ZLf2dGQ9gQ3YJl1eAd',
#       'name': 'Blind Melon',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sD1ZLf2dGQ9gQ3YJl1eAd'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/55jET4vDioHHd7ztX7OX3h'},
#     'href': 'https://api.spotify.com/v1/albums/55jET4vDioHHd7ztX7OX3h',
#     'id': '55jET4vDioHHd7ztX7OX3h',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737ed1df1690df31d094d7c2bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027ed1df1690df31d094d7c2bc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517ed1df1690df31d094d7c2bc',
#       'width': 64}],
#     'name': 'Blind Melon',
#     'release_date': '1992-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:55jET4vDioHHd7ztX7OX3h'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sD1ZLf2dGQ9gQ3YJl1eAd'},
#      'href': 'https://api.spotify.com/v1/artists/5sD1ZLf2dGQ9gQ3YJl1eAd',
#      'id': '5sD1ZLf2dGQ9gQ3YJl1eAd',
#      'name': 'Blind Melon',
#      'type': 'artist',
#      'uri': 'spotify:artist:5sD1ZLf2dGQ9gQ3YJl1eAd'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 217106,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCA29200194'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6txWz9UapYHVxEd7dDIHXT'},
#    'href': 'https://api.spotify.com/v1/tracks/6txWz9UapYHVxEd7dDIHXT',
#    'id': '6txWz9UapYHVxEd7dDIHXT',
#    'is_local': False,
#    'name': 'No Rain',
#    'popularity': 77,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:6txWz9UapYHVxEd7dDIHXT'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T17:59:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jJNGWrpjGIHUdTTJiIYeB'},
#       'href': 'https://api.spotify.com/v1/artists/0jJNGWrpjGIHUdTTJiIYeB',
#       'id': '0jJNGWrpjGIHUdTTJiIYeB',
#       'name': 'The Wallflowers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jJNGWrpjGIHUdTTJiIYeB'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2BOlaNQt6WJ1HO5pQcKHGh'},
#     'href': 'https://api.spotify.com/v1/albums/2BOlaNQt6WJ1HO5pQcKHGh',
#     'id': '2BOlaNQt6WJ1HO5pQcKHGh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e542fbcf1a83b7c726eb50a6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e542fbcf1a83b7c726eb50a6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e542fbcf1a83b7c726eb50a6',
#       'width': 64}],
#     'name': 'Bringing Down The Horse',
#     'release_date': '1996-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:2BOlaNQt6WJ1HO5pQcKHGh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jJNGWrpjGIHUdTTJiIYeB'},
#      'href': 'https://api.spotify.com/v1/artists/0jJNGWrpjGIHUdTTJiIYeB',
#      'id': '0jJNGWrpjGIHUdTTJiIYeB',
#      'name': 'The Wallflowers',
#      'type': 'artist',
#      'uri': 'spotify:artist:0jJNGWrpjGIHUdTTJiIYeB'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 312626,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR19600462'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0z1b34WikhOH9ZxU8QDWcv'},
#    'href': 'https://api.spotify.com/v1/tracks/0z1b34WikhOH9ZxU8QDWcv',
#    'id': '0z1b34WikhOH9ZxU8QDWcv',
#    'is_local': False,
#    'name': 'One Headlight',
#    'popularity': 74,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0z1b34WikhOH9ZxU8QDWcv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T17:59:21Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vEsuISMWAKNctLlUAhSZC'},
#       'href': 'https://api.spotify.com/v1/artists/0vEsuISMWAKNctLlUAhSZC',
#       'id': '0vEsuISMWAKNctLlUAhSZC',
#       'name': 'Counting Crows',
#       'type': 'artist',
#       'uri': 'spotify:artist:0vEsuISMWAKNctLlUAhSZC'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'TJ',
#      'VE',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4nKfZbCALT9H9LfedtDwnZ'},
#     'href': 'https://api.spotify.com/v1/albums/4nKfZbCALT9H9LfedtDwnZ',
#     'id': '4nKfZbCALT9H9LfedtDwnZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737e09670f90cd47b3fb9a23e0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027e09670f90cd47b3fb9a23e0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517e09670f90cd47b3fb9a23e0',
#       'width': 64}],
#     'name': 'August And Everything After',
#     'release_date': '1993-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4nKfZbCALT9H9LfedtDwnZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0vEsuISMWAKNctLlUAhSZC'},
#      'href': 'https://api.spotify.com/v1/artists/0vEsuISMWAKNctLlUAhSZC',
#      'id': '0vEsuISMWAKNctLlUAhSZC',
#      'name': 'Counting Crows',
#      'type': 'artist',
#      'uri': 'spotify:artist:0vEsuISMWAKNctLlUAhSZC'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'TJ',
#     'VE',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 272293,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR10000287'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5DiXcVovI0FcY2s0icWWUu'},
#    'href': 'https://api.spotify.com/v1/tracks/5DiXcVovI0FcY2s0icWWUu',
#    'id': '5DiXcVovI0FcY2s0icWWUu',
#    'is_local': False,
#    'name': 'Mr. Jones',
#    'popularity': 81,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5DiXcVovI0FcY2s0icWWUu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T17:59:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qXwLwTLdA44HYsA26vaNU'},
#       'href': 'https://api.spotify.com/v1/artists/6qXwLwTLdA44HYsA26vaNU',
#       'id': '6qXwLwTLdA44HYsA26vaNU',
#       'name': 'Tonic',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qXwLwTLdA44HYsA26vaNU'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6IQxEwIABLLej0bEYdrB0V'},
#     'href': 'https://api.spotify.com/v1/albums/6IQxEwIABLLej0bEYdrB0V',
#     'id': '6IQxEwIABLLej0bEYdrB0V',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f9a205a1a377506ff51b1a25',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f9a205a1a377506ff51b1a25',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f9a205a1a377506ff51b1a25',
#       'width': 64}],
#     'name': 'Lemon Parade',
#     'release_date': '1996-07-15',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6IQxEwIABLLej0bEYdrB0V'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qXwLwTLdA44HYsA26vaNU'},
#      'href': 'https://api.spotify.com/v1/artists/6qXwLwTLdA44HYsA26vaNU',
#      'id': '6qXwLwTLdA44HYsA26vaNU',
#      'name': 'Tonic',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qXwLwTLdA44HYsA26vaNU'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 261519,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USPR39609309'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4KoNBTm9a55KgLMtEaf3n6'},
#    'href': 'https://api.spotify.com/v1/tracks/4KoNBTm9a55KgLMtEaf3n6',
#    'id': '4KoNBTm9a55KgLMtEaf3n6',
#    'is_local': False,
#    'name': 'If You Could Only See',
#    'popularity': 69,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:4KoNBTm9a55KgLMtEaf3n6'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T17:59:23Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#       'href': 'https://api.spotify.com/v1/artists/2sil8z5kiy4r76CRTXxBCA',
#       'id': '2sil8z5kiy4r76CRTXxBCA',
#       'name': 'The Goo Goo Dolls',
#       'type': 'artist',
#       'uri': 'spotify:artist:2sil8z5kiy4r76CRTXxBCA'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4UMjBXcRqIgMZ1XumU2x5T'},
#     'href': 'https://api.spotify.com/v1/albums/4UMjBXcRqIgMZ1XumU2x5T',
#     'id': '4UMjBXcRqIgMZ1XumU2x5T',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eda9478c39a21e1cdc6609ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eda9478c39a21e1cdc6609ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eda9478c39a21e1cdc6609ca',
#       'width': 64}],
#     'name': 'Dizzy up the Girl',
#     'release_date': '1998-09-11',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:4UMjBXcRqIgMZ1XumU2x5T'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#      'href': 'https://api.spotify.com/v1/artists/2sil8z5kiy4r76CRTXxBCA',
#      'id': '2sil8z5kiy4r76CRTXxBCA',
#      'name': 'The Goo Goo Dolls',
#      'type': 'artist',
#      'uri': 'spotify:artist:2sil8z5kiy4r76CRTXxBCA'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'FM',
#     'NA',
#     'NE',
#     'PG',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TT',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 212066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USWB19800781'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0nnwn7LWHCAu09jfuH1xTA'},
#    'href': 'https://api.spotify.com/v1/tracks/0nnwn7LWHCAu09jfuH1xTA',
#    'id': '0nnwn7LWHCAu09jfuH1xTA',
#    'is_local': False,
#    'name': 'Slide',
#    'popularity': 74,
# ...
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7Go0PMnUuQcoodm4GQQP84'},
#     'href': 'https://api.spotify.com/v1/albums/7Go0PMnUuQcoodm4GQQP84',
#     'id': '7Go0PMnUuQcoodm4GQQP84',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e4b4dae541b5ac86d901d29c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e4b4dae541b5ac86d901d29c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e4b4dae541b5ac86d901d29c',
#       'width': 64}],
#     'name': 'This is Acoustic (Live Session / Acoustic Version)',
#     'release_date': '2015-12-04',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:7Go0PMnUuQcoodm4GQQP84'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3NPpFNZtSTHheNBaWC82rB'},
#      'href': 'https://api.spotify.com/v1/artists/3NPpFNZtSTHheNBaWC82rB',
#      'id': '3NPpFNZtSTHheNBaWC82rB',
#      'name': 'X Ambassadors',
#      'type': 'artist',
#      'uri': 'spotify:artist:3NPpFNZtSTHheNBaWC82rB'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 181986,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71516676'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1G3aUus1vknwZhl3CrsbUp'},
#    'href': 'https://api.spotify.com/v1/tracks/1G3aUus1vknwZhl3CrsbUp',
#    'id': '1G3aUus1vknwZhl3CrsbUp',
#    'is_local': False,
#    'name': 'Renegades - Live Session / Acoustic Version',
#    'popularity': 49,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1G3aUus1vknwZhl3CrsbUp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T19:24:48Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#       'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#       'id': '00FQb4jTyendYWaN8pK0wa',
#       'name': 'Lana Del Rey',
#       'type': 'artist',
#       'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'}],
#     'available_markets': ['AR',
#      'AU',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'RW',
#      'TG',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7xYiTrbTL57QO0bb4hXIKo'},
#     'href': 'https://api.spotify.com/v1/albums/7xYiTrbTL57QO0bb4hXIKo',
#     'id': '7xYiTrbTL57QO0bb4hXIKo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395e2fd1accb339fa14878190',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295e2fd1accb339fa14878190',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195e2fd1accb339fa14878190',
#       'width': 64}],
#     'name': 'Lust For Life',
#     'release_date': '2017-07-21',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:7xYiTrbTL57QO0bb4hXIKo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa'},
#      'href': 'https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa',
#      'id': '00FQb4jTyendYWaN8pK0wa',
#      'name': 'Lana Del Rey',
#      'type': 'artist',
#      'uri': 'spotify:artist:00FQb4jTyendYWaN8pK0wa'}],
#    'available_markets': ['AR',
#     'AU',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'RW',
#     'TG',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 272742,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71604605'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Kerz9H9IejzeIpjhDJoYG'},
#    'href': 'https://api.spotify.com/v1/tracks/2Kerz9H9IejzeIpjhDJoYG',
#    'id': '2Kerz9H9IejzeIpjhDJoYG',
#    'is_local': False,
#    'name': 'Love',
#    'popularity': 71,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2Kerz9H9IejzeIpjhDJoYG'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-01-03T19:24:48Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/meganishly'},
#    'href': 'https://api.spotify.com/v1/users/meganishly',
#    'id': 'meganishly',
#    'type': 'user',
#    'uri': 'spotify:user:meganishly'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZED1XzwlLHW4ZaG4lOT6m'},
#       'href': 'https://api.spotify.com/v1/artists/0ZED1XzwlLHW4ZaG4lOT6m',
#       'id': '0ZED1XzwlLHW4ZaG4lOT6m',
#       'name': 'Julia Michaels',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZED1XzwlLHW4ZaG4lOT6m'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1qyjZGIeeLJlXbYWuoloWj'},
#     'href': 'https://api.spotify.com/v1/albums/1qyjZGIeeLJlXbYWuoloWj',
#     'id': '1qyjZGIeeLJlXbYWuoloWj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a5acfd33d055ca075b829cc1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a5acfd33d055ca075b829cc1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a5acfd33d055ca075b829cc1',
#       'width': 64}],
#     'name': 'Nervous System',
#     'release_date': '2017-07-28',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:1qyjZGIeeLJlXbYWuoloWj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZED1XzwlLHW4ZaG4lOT6m'},
#      'href': 'https://api.spotify.com/v1/artists/0ZED1XzwlLHW4ZaG4lOT6m',
#      'id': '0ZED1XzwlLHW4ZaG4lOT6m',
#      'name': 'Julia Michaels',
#      'type': 'artist',
#      'uri': 'spotify:artist:0ZED1XzwlLHW4ZaG4lOT6m'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 176320,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71615691'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7vu0JkJh0ldukEYbTVcqd0'},
#    'href': 'https://api.spotify.com/v1/tracks/7vu0JkJh0ldukEYbTVcqd0',
#    'id': '7vu0JkJh0ldukEYbTVcqd0',
#    'is_local': False,
#    'name': 'Issues',
#    'popularity': 79,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7vu0JkJh0ldukEYbTVcqd0'},
#   'video_thumbnail': {'url': None}}]

# %%
# Each page is limited to 100 tracks, we will have to fix it:
len(playlist["items"])
# Out:
# 100

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("5zM1HJ9E3eNw3AdjG4qv9X")
len(all_tracks)
# Out:
# 4211

# %%
# Create new dataframe jason normalize our function return
tracks_playlist2_normalized = json_normalize(all_tracks)

# %%
tracks_playlist2_normalized.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2019-01-03T17:56:15Z     False          None
# 1  2019-01-03T17:56:22Z     False          None
# 2  2019-01-03T17:56:47Z     False          None
# 3  2019-01-03T17:59:08Z     False          None
# 4  2019-01-03T17:59:13Z     False          None
#
#              added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/meganishly
# 1  https://open.spotify.com/user/meganishly
# 2  https://open.spotify.com/user/meganishly
# 3  https://open.spotify.com/user/meganishly
# 4  https://open.spotify.com/user/meganishly
#
#                                  added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/meganishly  meganishly          user
# 1  https://api.spotify.com/v1/users/meganishly  meganishly          user
# 2  https://api.spotify.com/v1/users/meganishly  meganishly          user
# 3  https://api.spotify.com/v1/users/meganishly  meganishly          user
# 4  https://api.spotify.com/v1/users/meganishly  meganishly          user
#
#               added_by.uri track.album.album_type  \
# 0  spotify:user:meganishly                  album
# 1  spotify:user:meganishly            compilation
# 2  spotify:user:meganishly                  album
# 3  spotify:user:meganishly                  album
# 4  spotify:user:meganishly                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local                      track.name  \
# 0  4o7ZPI2fmEi3piRe0Hrfpy          False                    Hey Jealousy
# 1  2Y8i6ntDzXIhCO4UJPl5Qv          False   Superstition - Single Version
# 2  62LJFaYihsdVrrkgUOJC05          False                            Kiss
# 3  5b88tNINg4Q4nrRbrCXUmg          False  Happy - From "Despicable Me 2"
# 4  6txWz9UapYHVxEd7dDIHXT          False                         No Rain
#
#   track.popularity                                  track.preview_url  \
# 0               66                                               None
# 1                0                                               None
# 2               76  https://p.scdn.co/mp3-preview/390cf478a1f3fbdc...
# 3                4                                               None
# 4               77                                               None
#
#   track.track track.track_number track.type  \
# 0        True                  2      track
# 1        True                  9      track
# 2        True                 10      track
# 3        True                  5      track
# 4        True                  7      track
#
#                               track.uri video_thumbnail.url
# 0  spotify:track:4o7ZPI2fmEi3piRe0Hrfpy                None
# 1  spotify:track:2Y8i6ntDzXIhCO4UJPl5Qv                None
# 2  spotify:track:62LJFaYihsdVrrkgUOJC05                None
# 3  spotify:track:5b88tNINg4Q4nrRbrCXUmg                None
# 4  spotify:track:6txWz9UapYHVxEd7dDIHXT                None
#
# [5 rows x 40 columns]

# %%
# a list of dict is less easy to handle than a dict of dicts, so we create that insted
#def list_to_dict(x):
    #return {i: x[i] for i in range(len(x))}

# %%
#def list_to_dict(x):
    #if isinstance(x, list):
        #return {i: x[i] for i in range(len(x))}
    #elif isinstance(x, dict):
        #return x
    #else:
        #return {}

# %%
 #Here the code to only choose the dictionaries and not the lists:

def expand_list_dict2(row):
    artists_data = row['track.artists']
    if isinstance(artists_data, list):
        artists_data = [artist for artist in artists_data if isinstance(artist, dict)]
        if artists_data:
            df = json_normalize(artists_data)
            df['song_id'] = row['track.id']
            return df
    return None


tracks_playlist2_normalized['artists_dfs'] = tracks_playlist2_normalized.apply(expand_list_dict2, axis=1)
tracks_playlist2_normalized['artists_dfs'][2]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/5a2EaR3hamo...  5a2EaR3hamoenG9rDuVn8j
#
#      name    type                                    uri  \
# 0  Prince  artist  spotify:artist:5a2EaR3hamoenG9rDuVn8j
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/5a2EaR3hamoenG...  62LJFaYihsdVrrkgUOJC05

# %%
# now we create a new dataframe with all these artists
artist_df2 = pd.DataFrame(columns=['external_urls', 'href', 'id', 'name', 'type', 'uri'])
for val in tracks_playlist2_normalized['artists_dfs']:
    #display(val)
    artist_df2 = pd.concat([artist_df2, val], axis=0)
    
artist_df2
# Out:
#    external_urls                                               href  \
# 0            NaN  https://api.spotify.com/v1/artists/6kXp61QMZFP...
# 0            NaN  https://api.spotify.com/v1/artists/7guDJrEfX3q...
# 0            NaN  https://api.spotify.com/v1/artists/5a2EaR3hamo...
# 0            NaN  https://api.spotify.com/v1/artists/2RdwBSPQiwc...
# 0            NaN  https://api.spotify.com/v1/artists/5sD1ZLf2dGQ...
# ..           ...                                                ...
# 0            NaN  https://api.spotify.com/v1/artists/3NyhqlGrCiD...
# 0            NaN  https://api.spotify.com/v1/artists/3NyhqlGrCiD...
# 0            NaN  https://api.spotify.com/v1/artists/3NyhqlGrCiD...
# 1            NaN  https://api.spotify.com/v1/artists/2BGVeLLP31G...
# 2            NaN  https://api.spotify.com/v1/artists/0QG9fHGq9Cn...
#
#                         id               name    type  \
# 0   6kXp61QMZFPcKMcRPqoiVj       Gin Blossoms  artist
# 0   7guDJrEfX3qb6FEbdPA5qi      Stevie Wonder  artist
# 0   5a2EaR3hamoenG9rDuVn8j             Prince  artist
# 0   2RdwBSPQiwcmiDo9kixcl8  Pharrell Williams  artist
# 0   5sD1ZLf2dGQ9gQ3YJl1eAd        Blind Melon  artist
# ..                     ...                ...     ...
# 0   3NyhqlGrCiD2D8Ke3EpAEf   Champagne Jacket  artist
# 0   3NyhqlGrCiD2D8Ke3EpAEf   Champagne Jacket  artist
# 0   3NyhqlGrCiD2D8Ke3EpAEf   Champagne Jacket  artist
# 1   2BGVeLLP31GaUfBead5Wnj         Dana Ariel  artist
# 2   0QG9fHGq9CnASijMNuU0WD              Maesa  artist
#
#                                       uri  \
# 0   spotify:artist:6kXp61QMZFPcKMcRPqoiVj
# 0   spotify:artist:7guDJrEfX3qb6FEbdPA5qi
# 0   spotify:artist:5a2EaR3hamoenG9rDuVn8j
# 0   spotify:artist:2RdwBSPQiwcmiDo9kixcl8
# 0   spotify:artist:5sD1ZLf2dGQ9gQ3YJl1eAd
# ..                                    ...
# 0   spotify:artist:3NyhqlGrCiD2D8Ke3EpAEf
# 0   spotify:artist:3NyhqlGrCiD2D8Ke3EpAEf
# 0   spotify:artist:3NyhqlGrCiD2D8Ke3EpAEf
# 1   spotify:artist:2BGVeLLP31GaUfBead5Wnj
# 2   spotify:artist:0QG9fHGq9CnASijMNuU0WD
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/6kXp61QMZFPcKM...  4o7ZPI2fmEi3piRe0Hrfpy
# 0   https://open.spotify.com/artist/7guDJrEfX3qb6F...  2Y8i6ntDzXIhCO4UJPl5Qv
# 0   https://open.spotify.com/artist/5a2EaR3hamoenG...  62LJFaYihsdVrrkgUOJC05
# 0   https://open.spotify.com/artist/2RdwBSPQiwcmiD...  5b88tNINg4Q4nrRbrCXUmg
# 0   https://open.spotify.com/artist/5sD1ZLf2dGQ9gQ...  6txWz9UapYHVxEd7dDIHXT
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/3NyhqlGrCiD2D8...  6FzvvKMNsaYw39vonlunuE
# 0   https://open.spotify.com/artist/3NyhqlGrCiD2D8...  6er5sCEpIeNqO2ttPplKA4
# 0   https://open.spotify.com/artist/3NyhqlGrCiD2D8...  0QrglzVIBWBWoziOrV3z33
# 1   https://open.spotify.com/artist/2BGVeLLP31GaUf...  0QrglzVIBWBWoziOrV3z33
# 2   https://open.spotify.com/artist/0QG9fHGq9CnASi...  0QrglzVIBWBWoziOrV3z33
#
# [4639 rows x 8 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged2 = pd.merge(left=tracks_playlist2_normalized,
                    right=artist_df2,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged2.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2019-01-03T17:56:15Z     False          None
# 1  2019-01-03T17:56:22Z     False          None
# 2  2019-01-03T17:56:47Z     False          None
# 3  2019-01-03T17:59:08Z     False          None
# 4  2019-01-03T17:59:13Z     False          None
#
#              added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/meganishly
# 1  https://open.spotify.com/user/meganishly
# 2  https://open.spotify.com/user/meganishly
# 3  https://open.spotify.com/user/meganishly
# 4  https://open.spotify.com/user/meganishly
#
#                                  added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/meganishly  meganishly          user
# 1  https://api.spotify.com/v1/users/meganishly  meganishly          user
# 2  https://api.spotify.com/v1/users/meganishly  meganishly          user
# 3  https://api.spotify.com/v1/users/meganishly  meganishly          user
# 4  https://api.spotify.com/v1/users/meganishly  meganishly          user
#
#               added_by.uri track.album.album_type  \
# 0  spotify:user:meganishly                  album
# 1  spotify:user:meganishly            compilation
# 2  spotify:user:meganishly                  album
# 3  spotify:user:meganishly                  album
# 4  spotify:user:meganishly                  album
#
#                                  track.album.artists  ... video_thumbnail.url  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...                None
#
#                                          artists_dfs external_urls  \
# 0                                                ...           NaN
# 1                                                ...           NaN
# 2                                                ...           NaN
# 3                                                ...           NaN
# 4                                                ...           NaN
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/6kXp61QMZFP...  6kXp61QMZFPcKMcRPqoiVj
# 1  https://api.spotify.com/v1/artists/7guDJrEfX3q...  7guDJrEfX3qb6FEbdPA5qi
# 2  https://api.spotify.com/v1/artists/5a2EaR3hamo...  5a2EaR3hamoenG9rDuVn8j
# 3  https://api.spotify.com/v1/artists/2RdwBSPQiwc...  2RdwBSPQiwcmiDo9kixcl8
# 4  https://api.spotify.com/v1/artists/5sD1ZLf2dGQ...  5sD1ZLf2dGQ9gQ3YJl1eAd
#
#                 name    type                                    uri  \
# 0       Gin Blossoms  artist  spotify:artist:6kXp61QMZFPcKMcRPqoiVj
# 1      Stevie Wonder  artist  spotify:artist:7guDJrEfX3qb6FEbdPA5qi
# 2             Prince  artist  spotify:artist:5a2EaR3hamoenG9rDuVn8j
# 3  Pharrell Williams  artist  spotify:artist:2RdwBSPQiwcmiDo9kixcl8
# 4        Blind Melon  artist  spotify:artist:5sD1ZLf2dGQ9gQ3YJl1eAd
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/6kXp61QMZFPcKM...  4o7ZPI2fmEi3piRe0Hrfpy
# 1  https://open.spotify.com/artist/7guDJrEfX3qb6F...  2Y8i6ntDzXIhCO4UJPl5Qv
# 2  https://open.spotify.com/artist/5a2EaR3hamoenG...  62LJFaYihsdVrrkgUOJC05
# 3  https://open.spotify.com/artist/2RdwBSPQiwcmiD...  5b88tNINg4Q4nrRbrCXUmg
# 4  https://open.spotify.com/artist/5sD1ZLf2dGQ9gQ...  6txWz9UapYHVxEd7dDIHXT
#
# [5 rows x 49 columns]

# %%
df_final2 = df_merged2[['track.name', 'name', 'song_id']]
df_final2
# Out:
#                           track.name               name  \
# 0                       Hey Jealousy       Gin Blossoms
# 1      Superstition - Single Version      Stevie Wonder
# 2                               Kiss             Prince
# 3     Happy - From "Despicable Me 2"  Pharrell Williams
# 4                            No Rain        Blind Melon
# ...                              ...                ...
# 4794                           Sarah   Champagne Jacket
# 4795                         Tell Me   Champagne Jacket
# 4796                  Walls of China   Champagne Jacket
# 4797                  Walls of China         Dana Ariel
# 4798                  Walls of China              Maesa
#
#                      song_id
# 0     4o7ZPI2fmEi3piRe0Hrfpy
# 1     2Y8i6ntDzXIhCO4UJPl5Qv
# 2     62LJFaYihsdVrrkgUOJC05
# 3     5b88tNINg4Q4nrRbrCXUmg
# 4     6txWz9UapYHVxEd7dDIHXT
# ...                      ...
# 4794  6FzvvKMNsaYw39vonlunuE
# 4795  6er5sCEpIeNqO2ttPplKA4
# 4796  0QrglzVIBWBWoziOrV3z33
# 4797  0QrglzVIBWBWoziOrV3z33
# 4798  0QrglzVIBWBWoziOrV3z33
#
# [4799 rows x 3 columns]

# %%
# probably let them figure this out in the lab :-)
chunks = [(i, i+100) for i in range(0, len(df_final_1), 100)]
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final2['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 4874

# %%
audio_features_df_2 = json_normalize(audio_features_list)

# %%
df_w_audio_ft_2  = pd.merge(left=df_final2,
                        right=audio_features_df_2,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft_2
# Out:
#                           track.name               name  \
# 0                       Hey Jealousy       Gin Blossoms
# 1      Superstition - Single Version      Stevie Wonder
# 2                               Kiss             Prince
# 3     Happy - From "Despicable Me 2"  Pharrell Williams
# 4                            No Rain        Blind Melon
# ...                              ...                ...
# 7220                  Walls of China         Dana Ariel
# 7221                  Walls of China         Dana Ariel
# 7222                  Walls of China              Maesa
# 7223                  Walls of China              Maesa
# 7224                  Walls of China              Maesa
#
#                      song_id  danceability  energy   key  loudness  mode  \
# 0     4o7ZPI2fmEi3piRe0Hrfpy         0.471   0.797   6.0    -8.407   0.0
# 1     2Y8i6ntDzXIhCO4UJPl5Qv         0.643   0.628  10.0   -12.075   0.0
# 2     62LJFaYihsdVrrkgUOJC05         0.898   0.271   7.0   -12.238   1.0
# 3     5b88tNINg4Q4nrRbrCXUmg         0.647   0.822   5.0    -4.662   0.0
# 4     6txWz9UapYHVxEd7dDIHXT         0.389   0.476   9.0    -9.342   1.0
# ...                      ...           ...     ...   ...       ...   ...
# 7220  0QrglzVIBWBWoziOrV3z33         0.328   0.473  11.0    -6.922   0.0
# 7221  0QrglzVIBWBWoziOrV3z33         0.328   0.473  11.0    -6.922   0.0
# 7222  0QrglzVIBWBWoziOrV3z33         0.328   0.473  11.0    -6.922   0.0
# 7223  0QrglzVIBWBWoziOrV3z33         0.328   0.473  11.0    -6.922   0.0
# 7224  0QrglzVIBWBWoziOrV3z33         0.328   0.473  11.0    -6.922   0.0
#
#       speechiness  acousticness  ...  liveness  valence    tempo  \
# 0          0.0389      0.000179  ...    0.2990    0.497  152.903
# 1          0.0748      0.044300  ...    0.0359    0.894  100.392
# 2          0.0910      0.013500  ...    0.0461    0.742  111.485
# 3          0.1830      0.219000  ...    0.0908    0.962  160.019
# 4          0.0316      0.619000  ...    0.2550    0.566  148.117
# ...           ...           ...  ...       ...      ...      ...
# 7220       0.0333      0.597000  ...    0.1040    0.118  169.973
# 7221       0.0333      0.597000  ...    0.1040    0.118  169.973
# 7222       0.0333      0.597000  ...    0.1040    0.118  169.973
# 7223       0.0333      0.597000  ...    0.1040    0.118  169.973
# 7224       0.0333      0.597000  ...    0.1040    0.118  169.973
#
#                 type                      id  \
# 0     audio_features  4o7ZPI2fmEi3piRe0Hrfpy
# 1     audio_features  2Y8i6ntDzXIhCO4UJPl5Qv
# 2     audio_features  62LJFaYihsdVrrkgUOJC05
# 3     audio_features  5b88tNINg4Q4nrRbrCXUmg
# 4     audio_features  6txWz9UapYHVxEd7dDIHXT
# ...              ...                     ...
# 7220  audio_features  0QrglzVIBWBWoziOrV3z33
# 7221  audio_features  0QrglzVIBWBWoziOrV3z33
# 7222  audio_features  0QrglzVIBWBWoziOrV3z33
# 7223  audio_features  0QrglzVIBWBWoziOrV3z33
# 7224  audio_features  0QrglzVIBWBWoziOrV3z33
#
#                                        uri  \
# 0     spotify:track:4o7ZPI2fmEi3piRe0Hrfpy
# 1     spotify:track:2Y8i6ntDzXIhCO4UJPl5Qv
# 2     spotify:track:62LJFaYihsdVrrkgUOJC05
# 3     spotify:track:5b88tNINg4Q4nrRbrCXUmg
# 4     spotify:track:6txWz9UapYHVxEd7dDIHXT
# ...                                    ...
# 7220  spotify:track:0QrglzVIBWBWoziOrV3z33
# 7221  spotify:track:0QrglzVIBWBWoziOrV3z33
# 7222  spotify:track:0QrglzVIBWBWoziOrV3z33
# 7223  spotify:track:0QrglzVIBWBWoziOrV3z33
# 7224  spotify:track:0QrglzVIBWBWoziOrV3z33
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4o7ZPI2fmEi3...
# 1     https://api.spotify.com/v1/tracks/2Y8i6ntDzXIh...
# 2     https://api.spotify.com/v1/tracks/62LJFaYihsdV...
# 3     https://api.spotify.com/v1/tracks/5b88tNINg4Q4...
# 4     https://api.spotify.com/v1/tracks/6txWz9UapYHV...
# ...                                                 ...
# 7220  https://api.spotify.com/v1/tracks/0QrglzVIBWBW...
# 7221  https://api.spotify.com/v1/tracks/0QrglzVIBWBW...
# 7222  https://api.spotify.com/v1/tracks/0QrglzVIBWBW...
# 7223  https://api.spotify.com/v1/tracks/0QrglzVIBWBW...
# 7224  https://api.spotify.com/v1/tracks/0QrglzVIBWBW...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4o7Z...    236627.0
# 1     https://api.spotify.com/v1/audio-analysis/2Y8i...    245493.0
# 2     https://api.spotify.com/v1/audio-analysis/62LJ...    226240.0
# 3     https://api.spotify.com/v1/audio-analysis/5b88...    232720.0
# 4     https://api.spotify.com/v1/audio-analysis/6txW...    217107.0
# ...                                                 ...         ...
# 7220  https://api.spotify.com/v1/audio-analysis/0Qrg...    246588.0
# 7221  https://api.spotify.com/v1/audio-analysis/0Qrg...    246588.0
# 7222  https://api.spotify.com/v1/audio-analysis/0Qrg...    246588.0
# 7223  https://api.spotify.com/v1/audio-analysis/0Qrg...    246588.0
# 7224  https://api.spotify.com/v1/audio-analysis/0Qrg...    246588.0
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
# ...              ...
# 7220             3.0
# 7221             3.0
# 7222             3.0
# 7223             3.0
# 7224             3.0
#
# [7225 rows x 21 columns]

# %% [markdown]
# 3. Playlist https://open.spotify.com/playlist/4rnleEAOdmFAbRcNCgZMpY

# %%
# we will need more songs for our clustering
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

all_tracks = get_playlist_tracks("4rnleEAOdmFAbRcNCgZMpY")
len(all_tracks)
# Out:
# 5295

# %%
# Create new dataframe jason normalize our function return
tracks_playlist2_normalized = json_normalize(all_tracks)

# %%
 #Here the code to only choose the dictionaries and not the lists:

def expand_list_dict2(row):
    artists_data = row['track.artists']
    if isinstance(artists_data, list):
        artists_data = [artist for artist in artists_data if isinstance(artist, dict)]
        if artists_data:
            df = json_normalize(artists_data)
            df['song_id'] = row['track.id']
            return df
    return None


tracks_playlist2_normalized['artists_dfs'] = tracks_playlist2_normalized.apply(expand_list_dict2, axis=1)
tracks_playlist2_normalized['artists_dfs'][2]
# Out:
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/4V8LLVI7Pba...  4V8LLVI7PbaPR0K2TGSxFF
# 1  https://api.spotify.com/v1/artists/1U1el3k54Vv...  1U1el3k54VvEUzo3ybLPlM
#
#                  name    type                                    uri  \
# 0  Tyler, The Creator  artist  spotify:artist:4V8LLVI7PbaPR0K2TGSxFF
# 1          Kali Uchis  artist  spotify:artist:1U1el3k54VvEUzo3ybLPlM
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/4V8LLVI7PbaPR0...  7KA4W4McWYRpgf0fWsJZWB
# 1  https://open.spotify.com/artist/1U1el3k54VvEUz...  7KA4W4McWYRpgf0fWsJZWB

# %%
# now we create a new dataframe with all these artists
artist_df2 = pd.DataFrame(columns=['external_urls', 'href', 'id', 'name', 'type', 'uri'])
for val in tracks_playlist2_normalized['artists_dfs']:
    #display(val)
    artist_df2 = pd.concat([artist_df2, val], axis=0)
    
artist_df2
# Out:
#    external_urls                                               href  \
# 0            NaN  https://api.spotify.com/v1/artists/2FXC3k01G6G...
# 0            NaN  https://api.spotify.com/v1/artists/2KsP6tYLJlT...
# 1            NaN  https://api.spotify.com/v1/artists/1Bo8Afb2Qbj...
# 0            NaN  https://api.spotify.com/v1/artists/4V8LLVI7Pba...
# 1            NaN  https://api.spotify.com/v1/artists/1U1el3k54Vv...
# ..           ...                                                ...
# 0            NaN  https://api.spotify.com/v1/artists/1McMsnEElTh...
# 0            NaN  https://api.spotify.com/v1/artists/6veh5zbFpm3...
# 0            NaN  https://api.spotify.com/v1/artists/3PyJHH2wyfQ...
# 1            NaN  https://api.spotify.com/v1/artists/6lay1nwbE6h...
# 0            NaN  https://api.spotify.com/v1/artists/1U1el3k54Vv...
#
#                         id                name    type  \
# 0   2FXC3k01G6Gw61bmprjgqS              Hozier  artist
# 0   2KsP6tYLJlTBvSUxnwlVWa         Mike Posner  artist
# 1   1Bo8Afb2Qbjs4x6kJHyjle            Gigamesh  artist
# 0   4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator  artist
# 1   1U1el3k54VvEUzo3ybLPlM          Kali Uchis  artist
# ..                     ...                 ...     ...
# 0   1McMsnEElThX1knmY4oliG      Olivia Rodrigo  artist
# 0   6veh5zbFpm31XsPdjBgPER                 BIA  artist
# 0   3PyJHH2wyfQK3WZrk9rpmP            Ashnikko  artist
# 1   6lay1nwbE6hTx1jivysUAL      Princess Nokia  artist
# 0   1U1el3k54VvEUzo3ybLPlM          Kali Uchis  artist
#
#                                       uri  \
# 0   spotify:artist:2FXC3k01G6Gw61bmprjgqS
# 0   spotify:artist:2KsP6tYLJlTBvSUxnwlVWa
# 1   spotify:artist:1Bo8Afb2Qbjs4x6kJHyjle
# 0   spotify:artist:4V8LLVI7PbaPR0K2TGSxFF
# 1   spotify:artist:1U1el3k54VvEUzo3ybLPlM
# ..                                    ...
# 0   spotify:artist:1McMsnEElThX1knmY4oliG
# 0   spotify:artist:6veh5zbFpm31XsPdjBgPER
# 0   spotify:artist:3PyJHH2wyfQK3WZrk9rpmP
# 1   spotify:artist:6lay1nwbE6hTx1jivysUAL
# 0   spotify:artist:1U1el3k54VvEUzo3ybLPlM
#
#                                 external_urls.spotify                 song_id
# 0   https://open.spotify.com/artist/2FXC3k01G6Gw61...  7dS5EaCoMnN7DzlpT6aRn2
# 0   https://open.spotify.com/artist/2KsP6tYLJlTBvS...  2V4bv1fNWfTcyRJKmej6Sj
# 1   https://open.spotify.com/artist/1Bo8Afb2Qbjs4x...  2V4bv1fNWfTcyRJKmej6Sj
# 0   https://open.spotify.com/artist/4V8LLVI7PbaPR0...  7KA4W4McWYRpgf0fWsJZWB
# 1   https://open.spotify.com/artist/1U1el3k54VvEUz...  7KA4W4McWYRpgf0fWsJZWB
# ..                                                ...                     ...
# 0   https://open.spotify.com/artist/1McMsnEElThX1k...  61KpQadow081I2AsbeLcsb
# 0   https://open.spotify.com/artist/6veh5zbFpm31Xs...  5yorXJWdBan1Vlh116ZtQ7
# 0   https://open.spotify.com/artist/3PyJHH2wyfQK3W...  11ZulcYY4lowvcQm4oe3VJ
# 1   https://open.spotify.com/artist/6lay1nwbE6hTx1...  11ZulcYY4lowvcQm4oe3VJ
# 0   https://open.spotify.com/artist/1U1el3k54VvEUz...  6tDDoYIxWvMLTdKpjFkc1B
#
# [7739 rows x 8 columns]

# %%
# now we merge (join) the two dataframes, keeping only the fields we need
df_merged2 = pd.merge(left=tracks_playlist2_normalized,
                    right=artist_df2,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged2.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-06-09T17:34:13Z     False          None
# 1  2017-06-29T20:42:16Z     False          None
# 2  2017-06-29T20:42:16Z     False          None
# 3  2018-07-19T15:34:54Z     False          None
# 4  2018-07-19T15:34:54Z     False          None
#
#              added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/1130225252
# 1  https://open.spotify.com/user/1130225252
# 2  https://open.spotify.com/user/1130225252
# 3  https://open.spotify.com/user/1130225252
# 4  https://open.spotify.com/user/1130225252
#
#                                  added_by.href added_by.id added_by.type  \
# 0  https://api.spotify.com/v1/users/1130225252  1130225252          user
# 1  https://api.spotify.com/v1/users/1130225252  1130225252          user
# 2  https://api.spotify.com/v1/users/1130225252  1130225252          user
# 3  https://api.spotify.com/v1/users/1130225252  1130225252          user
# 4  https://api.spotify.com/v1/users/1130225252  1130225252          user
#
#               added_by.uri track.album.album_type  \
# 0  spotify:user:1130225252                  album
# 1  spotify:user:1130225252                  album
# 2  spotify:user:1130225252                  album
# 3  spotify:user:1130225252                  album
# 4  spotify:user:1130225252                  album
#
#                                  track.album.artists  ... video_thumbnail.url  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...                None
#
#                                          artists_dfs external_urls  \
# 0                                                ...           NaN
# 1                                                ...           NaN
# 2                                                ...           NaN
# 3                                                ...           NaN
# 4                                                ...           NaN
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/2FXC3k01G6G...  2FXC3k01G6Gw61bmprjgqS
# 1  https://api.spotify.com/v1/artists/2KsP6tYLJlT...  2KsP6tYLJlTBvSUxnwlVWa
# 2  https://api.spotify.com/v1/artists/1Bo8Afb2Qbj...  1Bo8Afb2Qbjs4x6kJHyjle
# 3  https://api.spotify.com/v1/artists/4V8LLVI7Pba...  4V8LLVI7PbaPR0K2TGSxFF
# 4  https://api.spotify.com/v1/artists/1U1el3k54Vv...  1U1el3k54VvEUzo3ybLPlM
#
#                  name    type                                    uri  \
# 0              Hozier  artist  spotify:artist:2FXC3k01G6Gw61bmprjgqS
# 1         Mike Posner  artist  spotify:artist:2KsP6tYLJlTBvSUxnwlVWa
# 2            Gigamesh  artist  spotify:artist:1Bo8Afb2Qbjs4x6kJHyjle
# 3  Tyler, The Creator  artist  spotify:artist:4V8LLVI7PbaPR0K2TGSxFF
# 4          Kali Uchis  artist  spotify:artist:1U1el3k54VvEUzo3ybLPlM
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/2FXC3k01G6Gw61...  7dS5EaCoMnN7DzlpT6aRn2
# 1  https://open.spotify.com/artist/2KsP6tYLJlTBvS...  2V4bv1fNWfTcyRJKmej6Sj
# 2  https://open.spotify.com/artist/1Bo8Afb2Qbjs4x...  2V4bv1fNWfTcyRJKmej6Sj
# 3  https://open.spotify.com/artist/4V8LLVI7PbaPR0...  7KA4W4McWYRpgf0fWsJZWB
# 4  https://open.spotify.com/artist/1U1el3k54VvEUz...  7KA4W4McWYRpgf0fWsJZWB
#
# [5 rows x 49 columns]

# %%
df_final3 = df_merged2[['track.name', 'name', 'song_id']]
df_final3
# Out:
#                                 track.name                name  \
# 0                        Take Me To Church              Hozier
# 1              Cooler Than Me - Single Mix         Mike Posner
# 2              Cooler Than Me - Single Mix            Gigamesh
# 3         See You Again (feat. Kali Uchis)  Tyler, The Creator
# 4         See You Again (feat. Kali Uchis)          Kali Uchis
# ...                                    ...                 ...
# 7744                               deja vu      Olivia Rodrigo
# 7745                     WHOLE LOTTA MONEY                 BIA
# 7746  Slumber Party (feat. Princess Nokia)            Ashnikko
# 7747  Slumber Party (feat. Princess Nokia)      Princess Nokia
# 7748                             telepatía          Kali Uchis
#
#                      song_id
# 0     7dS5EaCoMnN7DzlpT6aRn2
# 1     2V4bv1fNWfTcyRJKmej6Sj
# 2     2V4bv1fNWfTcyRJKmej6Sj
# 3     7KA4W4McWYRpgf0fWsJZWB
# 4     7KA4W4McWYRpgf0fWsJZWB
# ...                      ...
# 7744  61KpQadow081I2AsbeLcsb
# 7745  5yorXJWdBan1Vlh116ZtQ7
# 7746  11ZulcYY4lowvcQm4oe3VJ
# 7747  11ZulcYY4lowvcQm4oe3VJ
# 7748  6tDDoYIxWvMLTdKpjFkc1B
#
# [7749 rows x 3 columns]

# %%
# probably let them figure this out in the lab :-)
chunks = [(i, i+100) for i in range(0, len(df_final_1), 100)]
audio_features_list = []
for chunk in chunks:
    id_list100 = df_final3['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 7794

# %%
audio_features_df_3 = json_normalize(audio_features_list)

# %%
df_w_audio_ft_3 = pd.merge(left=df_final3,
                        right=audio_features_df_3,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft_3
# Out:
#                                  track.name            name  \
# 0                         Take Me To Church          Hozier
# 1               Cooler Than Me - Single Mix     Mike Posner
# 2               Cooler Than Me - Single Mix     Mike Posner
# 3               Cooler Than Me - Single Mix        Gigamesh
# 4               Cooler Than Me - Single Mix        Gigamesh
# ...                                     ...             ...
# 14766  Slumber Party (feat. Princess Nokia)        Ashnikko
# 14767  Slumber Party (feat. Princess Nokia)        Ashnikko
# 14768  Slumber Party (feat. Princess Nokia)  Princess Nokia
# 14769  Slumber Party (feat. Princess Nokia)  Princess Nokia
# 14770                             telepatía      Kali Uchis
#
#                       song_id  danceability  energy   key  loudness  mode  \
# 0      7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664   4.0    -5.303   0.0
# 1      2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820   7.0    -4.630   0.0
# 2      2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820   7.0    -4.630   0.0
# 3      2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820   7.0    -4.630   0.0
# 4      2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820   7.0    -4.630   0.0
# ...                       ...           ...     ...   ...       ...   ...
# 14766  11ZulcYY4lowvcQm4oe3VJ         0.964   0.398  11.0    -8.981   0.0
# 14767  11ZulcYY4lowvcQm4oe3VJ         0.964   0.398  11.0    -8.981   0.0
# 14768  11ZulcYY4lowvcQm4oe3VJ         0.964   0.398  11.0    -8.981   0.0
# 14769  11ZulcYY4lowvcQm4oe3VJ         0.964   0.398  11.0    -8.981   0.0
# 14770  6tDDoYIxWvMLTdKpjFkc1B         0.653   0.524  11.0    -9.016   0.0
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.0464       0.63400  ...     0.116    0.437  128.945
# 1           0.0474       0.17900  ...     0.689    0.625  129.965
# 2           0.0474       0.17900  ...     0.689    0.625  129.965
# 3           0.0474       0.17900  ...     0.689    0.625  129.965
# 4           0.0474       0.17900  ...     0.689    0.625  129.965
# ...            ...           ...  ...       ...      ...      ...
# 14766       0.0795       0.00151  ...     0.101    0.563  105.012
# 14767       0.0795       0.00151  ...     0.101    0.563  105.012
# 14768       0.0795       0.00151  ...     0.101    0.563  105.012
# 14769       0.0795       0.00151  ...     0.101    0.563  105.012
# 14770       0.0502       0.11200  ...     0.203    0.553   83.970
#
#                  type                      id  \
# 0      audio_features  7dS5EaCoMnN7DzlpT6aRn2
# 1      audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 2      audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 3      audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 4      audio_features  2V4bv1fNWfTcyRJKmej6Sj
# ...               ...                     ...
# 14766  audio_features  11ZulcYY4lowvcQm4oe3VJ
# 14767  audio_features  11ZulcYY4lowvcQm4oe3VJ
# 14768  audio_features  11ZulcYY4lowvcQm4oe3VJ
# 14769  audio_features  11ZulcYY4lowvcQm4oe3VJ
# 14770  audio_features  6tDDoYIxWvMLTdKpjFkc1B
#
#                                         uri  \
# 0      spotify:track:7dS5EaCoMnN7DzlpT6aRn2
# 1      spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 2      spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 3      spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# 4      spotify:track:2V4bv1fNWfTcyRJKmej6Sj
# ...                                     ...
# 14766  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 14767  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 14768  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 14769  spotify:track:11ZulcYY4lowvcQm4oe3VJ
# 14770  spotify:track:6tDDoYIxWvMLTdKpjFkc1B
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
# 1      https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 2      https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 3      https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 4      https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# ...                                                  ...
# 14766  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 14767  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 14768  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 14769  https://api.spotify.com/v1/tracks/11ZulcYY4low...
# 14770  https://api.spotify.com/v1/tracks/6tDDoYIxWvML...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/7dS5...    241688.0
# 1      https://api.spotify.com/v1/audio-analysis/2V4b...    213293.0
# 2      https://api.spotify.com/v1/audio-analysis/2V4b...    213293.0
# 3      https://api.spotify.com/v1/audio-analysis/2V4b...    213293.0
# 4      https://api.spotify.com/v1/audio-analysis/2V4b...    213293.0
# ...                                                  ...         ...
# 14766  https://api.spotify.com/v1/audio-analysis/11Zu...    178405.0
# 14767  https://api.spotify.com/v1/audio-analysis/11Zu...    178405.0
# 14768  https://api.spotify.com/v1/audio-analysis/11Zu...    178405.0
# 14769  https://api.spotify.com/v1/audio-analysis/11Zu...    178405.0
# 14770  https://api.spotify.com/v1/audio-analysis/6tDD...    160191.0
#
#        time_signature
# 0                 4.0
# 1                 4.0
# 2                 4.0
# 3                 4.0
# 4                 4.0
# ...               ...
# 14766             4.0
# 14767             4.0
# 14768             4.0
# 14769             4.0
# 14770             4.0
#
# [14771 rows x 21 columns]

# %%
# Concatenating all the dataframes

# %%
songs_all = pd.concat([df_w_audio_ft, audio_features_df_2 , df_w_audio_ft_3], axis=0, ignore_index=True)

# %%
# Dropping duplicates

# %%
songs_all.drop_duplicates(inplace=True)

# %%
songs_all.shape
# Out:
# (23249, 21)

# %%
#saving the df as csv file
songs_all.to_csv('songs_all.csv', index=False)
